# %%
# %matplotlib notebook

# import modules
import random
import scipy.stats
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib import cm
from pathlib import Path
import os
cwd = os.getcwd()
#import statsmodels.stats.moment_helpers
#from datetime import datetime
#import multiprocessing as mp
import csv
import networkx as nx
from IPython.display import HTML
from matplotlib import animation
import networkx as nx

# %% [markdown]
# # Setup

# %% [markdown]
# ## Parameters

# %%
#if you fired on the LAST iter and go under target, decrease weights with stuff active on last step
#need a way to cancel out reinforcement of actions that lead to under-stimulation
# eg. fire -> turn away from stim -> don't fire -> decrease weights with stuff that fired
plotIter=360*2*20
nnodes=350
p_link=.1
leak=.25#
leaktype=1 #1 = leak a percentage, or 2 = leak a constant rate
lrate_wmat=.01
lrate_targ=.01
targ_min=1
sens_offset=20
movement_amp=10
input_amp=.75
spike_cost = .01
stim_speed = 1
noise_sd = 0#1
weight_sd_init = 1
effector_type = 1
acts_neg=0

# %%
np.exp(-1)
# Out:
# 0.36787944117144233

# %% [markdown]
# ## Set up sensor nodes and input connections

# %%
sensory_nodes=[]
input_wmat=np.zeros((2,nnodes))
# for row in range(input_wmat.shape[0]):
#     for col in range(nnodes):
#         input_wmat[row,col]=random.choices([0,input_amp], weights=(1-p_link,p_link), k=1)[0]
#         if input_wmat[row,col] > 0:
#             sensory_nodes.append(col)

for row in range(input_wmat.shape[0]):
    for col in range(nnodes):
        connect = random.choices([0,1], weights=(1-p_link,p_link), k=1)[0]
        if connect == 1:
            input_wmat[row,col] = input_amp#np.random.normal(0,weight_sd_init)
            sensory_nodes.append(col)

# %%
len(sensory_nodes)
# Out:
# 67

# %% [markdown]
# ## Set up internal weight matrix

# %%
link_mat = np.zeros((nnodes,nnodes))
for row in range(link_mat.shape[0]):
    for col in range(link_mat.shape[1]):
        if row == col:
            continue
        link_mat[row,col] = random.choices([0,1], weights=(1-p_link,p_link), k=1)[0]
# link_mat[:,:]=1
# np.fill_diagonal(link_mat,0)
        
wmat=np.zeros((nnodes,nnodes))
for row in range(wmat.shape[0]):
    inhibitory = random.choices([0,1],weights=(.75,.25),k=1)[0]
    for col in range(wmat.shape[1]):
        if link_mat[row,col] == 1:
            if inhibitory==1:
                wmat[row,col] = np.random.normal(-.75,.1)
            else:
                wmat[row,col] = np.random.normal(.75,.1)

start_wmat=wmat.copy()

# %%
net = nx.from_numpy_matrix(link_mat)
# nx.draw_networkx(net, arrows=True,width=.1,with_labels=False, node_size=5, pos = nx.shell_layout(net))
layout = nx.spring_layout(net)

# %%
effector_nodes=[]
output_wmat=np.zeros((nnodes,2))
for row in range(output_wmat.shape[0]):
    if row in sensory_nodes:
        continue
    for col in range(output_wmat.shape[1]):
        connect = random.choices([0,1], weights=(1-p_link,p_link), k=1)[0]
        if connect == 1:
            output_wmat[row,col]=1#np.random.normal(0,weight_sd_init)
            effector_nodes.append(row)

# %%
len(effector_nodes)
# Out:
# 50

# %%
list(set(sensory_nodes) & set(effector_nodes))
# Out:
# []

# %% [markdown]
# ## Functions

# %%
def get_plot_vals(degree, heading):
    x = np.cos(np.radians(degree))
    y = np.sin(np.radians(degree))
    
    sLdeg = heading + sens_offset
    if sLdeg > 360:
        sLdeg = sLdeg - 360
    sRdeg = heading - sens_offset
    if sRdeg < 0:
        sRdeg = 360 + sRdeg
        
    sLx = .5*np.cos(np.radians(sLdeg)) 
    sLy = .5*np.sin(np.radians(sLdeg)) 
    sLpos = np.array([sLx,sLy])
    
    sRx = .5*np.cos(np.radians(sRdeg)) 
    sRy = .5*np.sin(np.radians(sRdeg))
    sRpos = np.array([sRx, sRy])
    
    return x, y, sLx, sLy, sRx, sRy

def move_stim(degree, direction):
    if direction == 1:
        degree += stim_speed
    else:
        degree -= stim_speed
        
    if degree > 360:
        degree = degree - 360
    if degree < 0:
        degree = degree + 360

    return degree

def rotate_agent(output_acts, heading):
    diff = (output_acts[0] - output_acts[1])*movement_amp
    #diff = (output_spikes[0] - output_spikes[1])*movement_amp
    heading = heading + diff
    
    if heading > 360:
        heading = heading - 360
    if heading < 0:
        heading = heading + 360
    
    return heading

def get_input_acts(heading, degree):
    
    sLdeg = heading + sens_offset
    if sLdeg > 360:
        sLdeg = sLdeg - 360
    if sLdeg <0:
        sLdeg = sLdeg + 360
        
    dL = np.abs(degree - sLdeg)
    if dL > 180:
        dL = 360 - dL
        
    sRdeg = heading - sens_offset
    if sRdeg > 360:
        sRdeg = sRdeg - 360
    if sRdeg < 0:
        sRdeg = sRdeg + 360
        
    dR = np.abs(degree - sRdeg)
    if dR > 180:
        dR = 360 - dR
    
#     sL_act = 1-dL/180
#     sR_act = 1-dR/180
    
    if dL <= 60:
        sL_act = 1 - dL/60
    else:
        sL_act = 0
    
    if dR <= 60:
        sR_act = 1 - dR/60
    else:
        sR_act = 0
        
    return [sL_act, sR_act], [dL, dR]

def get_acts(acts,leak,spikes,wmat,input,input_wmat,targets, spike_rep):
    
    thresholds = targets*2
    
    acts = acts*(1-leak) + np.dot(input, input_wmat) + np.dot(spikes, wmat) + np.random.normal(0,noise_sd,size=nnodes)

    spikes[acts >= thresholds]=1
    spikes[acts < thresholds]=0
    
    # new stuff 
    if spike_cost>0:
        spike_rep[spikes==1]+=1
        spike_rep[spikes==0]=0
        spikes[spikes==1] -= (1-np.exp(-spike_rep[spikes==1]*spike_cost))
    
    acts[spikes>0]=acts[spikes>0]-thresholds[spikes>0]
    
    # setting negative acts back to 0 before accounting for errors seems important for tracking behavior - why?
    if acts_neg == 0:
        acts[acts<0]=0
        
    errors=acts-targets
    
    return acts, spikes, errors, spike_rep

def learning(learn_on,link_mat,spikes,prev_spikes, errors,wmat,targets):
    
    active_neighbors=link_mat.copy()
    active_neighbors[prev_spikes==0,:]=0
    d_wmat = active_neighbors.copy()
    active_neighbors=np.sum(active_neighbors,axis=0)#+np.repeat(1,nnodes)
    
    if learn_on==1:
        if np.sum(active_neighbors) >0:
            d_wmat = errors*d_wmat
            d_wmat=(d_wmat/active_neighbors)
            #d_wmat=(d_wmat/(active_neighbors+1))
            d_wmat=np.nan_to_num(d_wmat)
            wmat-=d_wmat
            
        #targets=targets+((errors/(active_neighbors+1))*lrate_targ)
        targets=targets+(errors*lrate_targ) 
        targets[targets<targ_min]=targ_min
            
        
    return wmat, targets

# %% [markdown]
# # Run the model

# %%
spikes=np.zeros(nnodes)
spike_rep=np.zeros(nnodes)
targets=np.repeat(targ_min,nnodes)
acts=np.zeros(nnodes)
input_acts = np.zeros(2)
output_acts = np.zeros(2)
# output_spikes = np.zeros(2)
# output_targets = np.repeat(targ_min,2)
MeanErs=[]
MeanActs =[]
MeanSpikes=[]

i=1
degree = 0
heading = 90
direction = 1
learn_on=1
def drawframe(n):
    global noise_sd,link_decay,spike_rep,direction,degree, heading, acts, input_acts, output_acts, leak, spikes, prev_spikes, wmat, input_wmat, output_wmat, targets, errors,MeanAbsErs,MeanActs,MeanSpikes
    
    #if n==(plotIter/2):#(n %  1440 == 0) and (n !=0):
    if (n %  720 == 0) and (n !=0):
        if direction == 1:
            direction = 2
        else:
            direction = 1
    
    input, dists = get_input_acts(heading, degree)
        
    prev_spikes = spikes.copy()
    
    acts, spikes, errors,spike_rep = get_acts(acts,leak,spikes,wmat,input,input_wmat,targets,spike_rep)
    
    output_acts = np.dot(spikes, output_wmat)/np.sum(output_wmat, axis=0)
        
    wmat, targets = learning(learn_on,link_mat,spikes,prev_spikes, errors, wmat,targets)
    
    x, y, sLx, sLy, sRx, sRy = get_plot_vals(degree, heading)
    
    degree = move_stim(degree, direction)
    heading = rotate_agent(output_acts, heading)
    
    txt_title1.set_text('Frame = {0:4d}'.format(n))
    txt_title2.set_text('M.Err = {0:f}'.format(np.round(np.mean(errors), decimals=2)))
    txt_title3.set_text('M.Act = {0:f}'.format(np.round(np.mean(acts), decimals=2)))

    pt1.set_data(x,y)
    sL.set_data(sLx,sLy)
    sR.set_data(sRx,sRy)
    bar1_plt2.set_height(input[0])
    bar2_plt2.set_height(input[1])
    bar1_plt3.set_height(output_acts[0])
    bar2_plt3.set_height(output_acts[1])
    
#     ax4.clear()
#     netfig=nx.draw_networkx(net,width=.1,with_labels=False, node_size=10, pos = layout, node_color=spikes)
#     bar1_plt5.set_height(np.mean(np.abs(acts)))
#     bar2_plt5.set_height(np.mean(np.abs(errors)))
#     bar3_plt5.set_height(np.mean(targets))
#     ax6.clear()
#     ax6.set_ylim((0,150))
#     ax6.set_xlim((-5,5))
#     ax6.hist(x=np.matrix.flatten(wmat[link_mat==1]), bins='auto', alpha=0.7, rwidth=0.85)
    
    
    if (n % 100 !=0):
        MeanEr = np.mean(errors)
        MeanErs.append(MeanEr)
        MeanAct = np.mean(acts)
        MeanActs.append(MeanAct)
        MeanSpike = np.mean(spikes)
        MeanSpikes.append(MeanSpike)
        #print('iteration: ', n, ' ; MeanAbsEr: ',MeanAbsEr, ' ; MeanAct: ', MeanAct)
    else:
        MeanEr = np.mean(errors)
        MeanErs.append(MeanEr)
        MeanAct = np.mean(acts)
        MeanActs.append(MeanAct)
        MeanSpike = np.mean(spikes)
        MeanSpikes.append(MeanSpike)
        
        MeanErs_ = np.round(np.mean(MeanErs),decimals=2)
        MeanActs_ = np.round(np.mean(MeanActs),decimals=2)
        MeanSpikes_ = np.round(np.mean(MeanSpikes),decimals=2)
        print('iteration: ', str(n), ' ; MeanErs: ',str(MeanErs_), ' ; MeanAct: ', str(MeanActs_), '; MeanSpikes: ', str(MeanSpikes_))
        MeanAbsErs=[]
        MeanActs=[]
        MeanSpikes=[]
    
    #txt_title2.set_text('MnAbsEr: ' + str(np.mean(np.abs(errors))) + ' ; MnAct: ' + str(np.mean(acts)) + '; MnSpk: ', str(np.mean(spikes)))
    #txt_title2.set_text('MnAbsEr = {0:4d}'.format(np.mean(np.abs(errors))))
    #txt_title2.set_text('iteration: ' + str(n))
    return (pt1,sL,sR)

# create a figure and axes
#fig = plt.figure(figsize=(12,8))
fig = plt.figure(figsize=(10,3))
ax1 = plt.subplot(1,3,1)
ax2 = plt.subplot(1,3,2)
ax3 = plt.subplot(1,3,3)

#ax4 = plt.subplot(2,3,4)
#ax5 = plt.subplot(2,3,5)
#ax6 = plt.subplot(2,3,6)

# set up the subplots as needed
ax1.set_xlim(( -1, 1))            
ax1.set_ylim((-1, 1))
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax2.set_ylim((0, 1))
ax3.set_ylim((0, 1))


# ax5.set_ylim((0,3))
# ax6.set_ylim((0,150))
# ax6.set_xlim((-5,5))

circle1 = plt.Circle((0, 0), 0.5, color='black', fill = 0)
ax1.add_patch(circle1)

# create objects that will change in the animation. These are
# initially empty, and will be given new values for each frame
# in the animation.

pt1, = ax1.plot([], [], 'g.', ms=30)
sL, = ax1.plot([],[], 'r.', ms =10)
sR, = ax1.plot([],[], 'b.', ms =10)
bar1_plt2, bar2_plt2 = ax2.bar(['sensor L', 'sensor R'],[0,0], color = ['r','b'])
bar1_plt3, bar2_plt3 = ax3.bar(['effector L', 'effector R'],[0,0], color = ['r','b'])


# plt.sca(ax4)
# netfig = nx.draw_networkx(net,width=.1,with_labels=False, node_size=10, pos = layout, node_color=spikes)
#bar1_plt5, bar2_plt5, bar3_plt5 = ax5.bar(['MAct','MErr', 'MTarget'],[0,0,0],color = 'black')
#ax6.hist(x=np.matrix.flatten(wmat[link_mat==1]), bins='auto',alpha=0.7, rwidth=0.85)

txt_title1 = ax1.set_title('')
txt_title2 = ax2.set_title('')
txt_title3 = ax3.set_title('')
# txt_title6 = ax6.set_title('Weight Dist.')

spikes=np.zeros(nnodes)
targets=np.repeat(targ_min,nnodes)
acts=np.zeros(nnodes)
input_acts = np.zeros(2)
output_acts = np.zeros(2)
# output_spikes = np.zeros(2)
# output_targets = np.repeat(targ_min,2)
MeanAbsErs=[]
MeanActs =[]
MeanSpikes = []
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
anim = animation.FuncAnimation(fig, drawframe, frames=plotIter, interval=20, blit=True)
#plt.show()
anim.save('MV_RotatingAgent2_X.mp4') #v1
# Out:
# iteration:  0  ; MeanErs:  -1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  0  ; MeanErs:  -1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# /Users/jbenfalandays/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:119: RuntimeWarning: invalid value encountered in true_divide
# iteration:  100  ; MeanErs:  -0.07  ; MeanAct:  1.06 ; MeanSpikes:  0.31
# iteration:  200  ; MeanErs:  -0.1  ; MeanAct:  0.98 ; MeanSpikes:  0.34
# iteration:  300  ; MeanErs:  -0.4  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  400  ; MeanErs:  -0.49  ; MeanAct:  0.21 ; MeanSpikes:  0.07
# iteration:  500  ; MeanErs:  -0.4  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  600  ; MeanErs:  -0.33  ; MeanAct:  1.05 ; MeanSpikes:  0.42
# iteration:  700  ; MeanErs:  -0.28  ; MeanAct:  1.04 ; MeanSpikes:  0.42
# iteration:  800  ; MeanErs:  -0.25  ; MeanAct:  1.06 ; MeanSpikes:  0.44
# iteration:  900  ; MeanErs:  -0.22  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  1000  ; MeanErs:  -0.2  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  1100  ; MeanErs:  -0.18  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  1200  ; MeanErs:  -0.17  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  1300  ; MeanErs:  -0.15  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  1400  ; MeanErs:  -0.14  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  1500  ; MeanErs:  -0.13  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  1600  ; MeanErs:  -0.12  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  1700  ; MeanErs:  -0.12  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  1800  ; MeanErs:  -0.11  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  1900  ; MeanErs:  -0.1  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  2000  ; MeanErs:  -0.1  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  2100  ; MeanErs:  -0.09  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  2200  ; MeanErs:  -0.09  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  2300  ; MeanErs:  -0.09  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  2400  ; MeanErs:  -0.08  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  2500  ; MeanErs:  -0.08  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  2600  ; MeanErs:  -0.08  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  2700  ; MeanErs:  -0.07  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  2800  ; MeanErs:  -0.07  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  2900  ; MeanErs:  -0.07  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  3000  ; MeanErs:  -0.07  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  3100  ; MeanErs:  -0.06  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  3200  ; MeanErs:  -0.06  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  3300  ; MeanErs:  -0.06  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  3400  ; MeanErs:  -0.06  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  3500  ; MeanErs:  -0.06  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  3600  ; MeanErs:  -0.06  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  3700  ; MeanErs:  -0.05  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  3800  ; MeanErs:  -0.05  ; MeanAct:  1.06 ; MeanSpikes:  0.44
# iteration:  3900  ; MeanErs:  -0.05  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  4000  ; MeanErs:  -0.05  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  4100  ; MeanErs:  -0.05  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  4200  ; MeanErs:  -0.05  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  4300  ; MeanErs:  -0.05  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  4400  ; MeanErs:  -0.05  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  4500  ; MeanErs:  -0.04  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  4600  ; MeanErs:  -0.04  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  4700  ; MeanErs:  -0.04  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  4800  ; MeanErs:  -0.04  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  4900  ; MeanErs:  -0.04  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  5000  ; MeanErs:  -0.04  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  5100  ; MeanErs:  -0.04  ; MeanAct:  1.06 ; MeanSpikes:  0.44
# iteration:  5200  ; MeanErs:  -0.04  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  5300  ; MeanErs:  -0.04  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  5400  ; MeanErs:  -0.04  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  5500  ; MeanErs:  -0.04  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  5600  ; MeanErs:  -0.04  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  5700  ; MeanErs:  -0.03  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  5800  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  5900  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  6000  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  6100  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  6200  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  6300  ; MeanErs:  -0.03  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  6400  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  6500  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  6600  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  6700  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  6800  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  6900  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  7000  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  7100  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  7200  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  7300  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  7400  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  7500  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  7600  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  7700  ; MeanErs:  -0.03  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  7800  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  7900  ; MeanErs:  -0.03  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  8000  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  8100  ; MeanErs:  -0.02  ; MeanAct:  1.06 ; MeanSpikes:  0.44
# iteration:  8200  ; MeanErs:  -0.02  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  8300  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  8400  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  8500  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  8600  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  8700  ; MeanErs:  -0.02  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  8800  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  8900  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  9000  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  9100  ; MeanErs:  -0.02  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  9200  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  9300  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  9400  ; MeanErs:  -0.02  ; MeanAct:  1.06 ; MeanSpikes:  0.44
# iteration:  9500  ; MeanErs:  -0.02  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  9600  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  9700  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  9800  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  9900  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  10000  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  10100  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  10200  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  10300  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  10400  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  10500  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  10600  ; MeanErs:  -0.02  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  10700  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  10800  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  10900  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  11000  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  11100  ; MeanErs:  -0.02  ; MeanAct:  1.06 ; MeanSpikes:  0.44
# iteration:  11200  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  11300  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  11400  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  11500  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  11600  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  11700  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  11800  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  11900  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  12000  ; MeanErs:  -0.02  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  12100  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  12200  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  12300  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  12400  ; MeanErs:  -0.02  ; MeanAct:  1.06 ; MeanSpikes:  0.44
# iteration:  12500  ; MeanErs:  -0.02  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  12600  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  12700  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  12800  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  12900  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  13000  ; MeanErs:  -0.02  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  13100  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  13200  ; MeanErs:  -0.02  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  13300  ; MeanErs:  -0.01  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  13400  ; MeanErs:  -0.01  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  13500  ; MeanErs:  -0.01  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  13600  ; MeanErs:  -0.01  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  13700  ; MeanErs:  -0.01  ; MeanAct:  1.06 ; MeanSpikes:  0.44
# iteration:  13800  ; MeanErs:  -0.01  ; MeanAct:  1.04 ; MeanSpikes:  0.44
# iteration:  13900  ; MeanErs:  -0.01  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  14000  ; MeanErs:  -0.01  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  14100  ; MeanErs:  -0.01  ; MeanAct:  1.06 ; MeanSpikes:  0.44
# iteration:  14200  ; MeanErs:  -0.01  ; MeanAct:  1.05 ; MeanSpikes:  0.44
# iteration:  14300  ; MeanErs:  -0.01  ; MeanAct:  1.05 ; MeanSpikes:  0.44

# %%
### alternate way to plot

# %%
#HTML(anim.to_html5_video())
