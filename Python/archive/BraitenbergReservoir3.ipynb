# %%
# %matplotlib notebook

# import modules
import random
import scipy.stats
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.colors import ListedColormap
from matplotlib import cm
from pathlib import Path
import os
cwd = os.getcwd()
#import statsmodels.stats.moment_helpers
#from datetime import datetime
#import multiprocessing as mp
import csv
import networkx as nx
from IPython.display import HTML
from matplotlib import animation
import networkx as nx

# %% [markdown]
# # Setup

# %% [markdown]
# ## Parameters

# %%
plotIter = 360*2*20
nnodes = 350
p_link = .05
leak = .25 #
leaktype = 1 #1 = leak a percentage, or 2 = leak a constant rate
lrate_wmat = .1
lrate_targ = .01
targ_min = 1 
sens_offset = 30
rot_amp = 1
input_amp = 5
forward_amp = .01
spike_cost = .1
stim_speed = 1
noise_sd = 0#.2
weight_sd_init = 1#5
effector_type = 1 # 1 = separate output nodes (totally untrained / non-allostatic), 2 = select random nodes in reservoir as output nodes (nodes are trained)
acts_neg=1

# %%
x=5*np.cos(np.radians(2))
y=5*np.sin(np.radians(2))

# %%
[x,y]
# Out:
# [4.9969541350954785, 0.17449748351250485]

# %% [markdown]
# ## Set up sensor nodes and input connections

# %%
sensory_nodes=[]
input_wmat=np.zeros((2,nnodes))
for row in range(input_wmat.shape[0]):
    for col in range(nnodes):
        input_wmat[row,col]=random.choices([0,input_amp], weights=(1-p_link,p_link), k=1)[0]
        if input_wmat[row,col] > 0:
            sensory_nodes.append(col)

# %%
len(sensory_nodes)
# Out:
# 37

# %% [markdown]
# ## Set up internal weight matrix

# %%
link_mat = np.zeros((nnodes,nnodes))
for row in range(link_mat.shape[0]):
    for col in range(link_mat.shape[1]):
        if row == col:
            continue
        link_mat[row,col] = random.choices([0,1], weights=(1-p_link,p_link), k=1)[0]
# link_mat[:,:]=1
# np.fill_diagonal(link_mat,0)
        
wmat=np.zeros((nnodes,nnodes))
for row in range(wmat.shape[0]):
    for col in range(wmat.shape[1]):
        if link_mat[row,col] == 1:
            wmat[row,col] = np.random.normal(0,weight_sd_init)
            
start_wmat=wmat.copy()

# %%
net = nx.from_numpy_matrix(wmat)
#nx.draw_networkx(net, arrows=True,width=.1,with_labels=False, node_size=5, pos = nx.shell_layout(net))
layout = nx.spring_layout(net)

# %%
effector_nodes=[]
if effector_type ==1:
    output_wmat=np.zeros((nnodes,4))
    for row in range(output_wmat.shape[0]):
        for col in range(output_wmat.shape[1]):
            output_wmat[row,col]=random.choices([0,1], weights=(1-p_link,p_link), k=1)[0]
            if output_wmat[row,col] > 0:
                effector_nodes.append(row)

    while len(list(set(sensory_nodes) & set(effector_nodes))) > 0:
        effector_nodes=[]
        output_wmat=np.zeros((nnodes,4))
        for row in range(output_wmat.shape[0]):
            for col in range(output_wmat.shape[1]):
                output_wmat[row,col]=random.choices([0,1], weights=(1-p_link,p_link), k=1)[0]
                if output_wmat[row,col] > 0:
                    effector_nodes.append(row)
else:       
    #select two random nodes to be output nodes
    effector_nodes = random.sample(range(1, nnodes), 4)
    while len(list(set(sensory_nodes) & set(effector_nodes))) > 0:
        effector_nodes = random.sample(range(1, nnodes), 4)

# %%
len(effector_nodes)
# Out:
# 46

# %%
list(set(sensory_nodes) & set(effector_nodes))
# Out:
# []

# %% [markdown]
# ## Functions

# %%
def get_plot_vals(degree, heading,position):
    x = 10*np.cos(np.radians(degree))
    y = 10*np.sin(np.radians(degree))
    
    sLdeg = heading + sens_offset
    if sLdeg >= 360:
        sLdeg = sLdeg - 360
    sRdeg = heading - sens_offset
    if sRdeg < 0:
        sRdeg = 360 + sRdeg
        
    sLx = .5*np.cos(np.radians(sLdeg)) + position[0]
    sLy = .5*np.sin(np.radians(sLdeg)) + position[1]
    sLpos = np.array([sLx,sLy])
    
    sRx = .5*np.cos(np.radians(sRdeg)) + position[0]
    sRy = .5*np.sin(np.radians(sRdeg)) + position[1]
    sRpos = np.array([sRx, sRy])
    
    return x, y, sLx, sLy, sRx, sRy

def move_stim(degree, direction):
    if direction == 1:
        degree += stim_speed
    else:
        degree -= stim_speed
        
    if degree > 360:
        degree = degree - 360
    if degree < 0:
        degree = degree + 360

    return degree

def rotate_agent(output_acts, heading):
    diff = (output_acts[0] - output_acts[1])*rot_amp
    #diff = (output_spikes[0] - output_spikes[1])*movement_amp
    heading = heading + diff
    
    if heading > 360:
        heading = heading - 360
    if heading < 0:
        heading = heading + 360
    
    return heading

def move_agent(output_acts, heading, position):
    
    diff = (output_acts[0] - output_acts[1])*rot_amp #rotates clockwise when left sensor is more active
    #diff = output_spikes[0] - output_spikes[1]
    heading = heading + diff
    
    if heading > 360:
        heading = heading - 360
    if heading < 0:
        heading = heading + 360
        
    #r = output_acts[2]*forward_amp
    r = (output_acts[2] - output_acts[3])*forward_amp
    dx = r * np.cos(np.radians(heading))
    dy = r * np.sin(np.radians(heading))
    position[0]+= dx
    position[1]+= dy

    # for euc dist
    if position[0] > 5:
        position[0] = 5
        
    if position[0] < -5:
        position[0] = -5
        
    if position[1] > 5:
        position[1] = 5
        
    if position[1] < -5:
        position[1] = -5
    
    return heading, position

def euc_dist(point1, point2):
    xdiff = abs(point1[0] - point2[0])
    ydiff = abs(point1[1] - point2[1])
    euc_dist = np.sqrt(xdiff**2 + ydiff**2)
    
    return euc_dist

def angle_between(position, heading, stim_pos):
    x = stim_pos[0]-position[0]
    y = stim_pos[1]-position[1]
    
    angle = np.arctan2(y, x) * 180 / np.pi
    #angle = np.degrees(np.arctan2(y, x))
    if angle < 0:
        angle = 360+angle
    
    angDist = angle - heading
    
    ang_dL = np.abs(angDist - sens_offset)
    if ang_dL > 180:
        ang_dL = 360 - ang_dL
    ang_dR = np.abs(angDist + sens_offset)
    if ang_dR > 180:
        ang_dR = 360 - ang_dR
    
    return angDist, ang_dL, ang_dR


def get_input_acts(heading, position, degree):
    
    stim_pos = [10*np.cos(np.radians(degree)),10*np.sin(np.radians(degree))]
    
    sLheading = heading + sens_offset
    if sLheading >= 360:
        sLheading = sLheading - 360
        
    sRheading = heading - sens_offset
    if sRheading < 0:
        sRheading = sRheading + 360
        
    sRx = .5*np.cos(np.radians(sRheading))+position[0]
    sRy = .5*np.sin(np.radians(sRheading))+position[1]
    sRpos = np.array([sRx, sRy])
    
    sLx = .5*np.cos(np.radians(sLheading)) +position[0]
    sLy = .5*np.sin(np.radians(sLheading)) + position[1]
    sLpos = np.array([sLx,sLy])
    
    dR = euc_dist(sRpos, np.array(stim_pos))#np.sqrt(np.sum(np.sqrt(np.array(stim_pos)-np.array([s1x,s1y]))))
    dL = euc_dist(sLpos, np.array(stim_pos))#np.sqrt(np.sum(np.sqrt(np.array(stim_pos)-np.array([s2x,s2y]))))

    angDist, ang_dL, ang_dR = angle_between(position, heading, stim_pos)
    
#     if ang_dL > 60:
#         ang_dL = 60
#     if ang_dR > 60:
#         ang_dR = 60
#
#     sL_act = (1 - ang_dL/60)*(1 - dL/np.sqrt(200))
#     sR_act = (1 - ang_dR/60)*(1 - dR/np.sqrt(200))
        
    if ang_dL <= 60:
        sL_act = 1 - ang_dL/60
    else:
        sL_act = 0
    
    if ang_dR <= 60:
        sR_act = 1 - ang_dR/60
    else:
        sR_act = 0

    return [sL_act, sR_act], [dL, dR], [ang_dL, ang_dR]

def get_acts(acts,leak,spikes,wmat,input,input_wmat,targets, spike_rep):
    thresholds = targets*2
    
    if leaktype == 1:
        acts = acts*(1-leak) + np.dot(input, input_wmat) + np.dot(spikes, wmat) + np.random.normal(0,noise_sd,size=nnodes)
    else:
        acts = acts-leak + np.dot(input, input_wmat) + np.dot(spikes, wmat) + np.random.normal(0,noise_sd,size=nnodes)

    spikes[acts >= thresholds]=1
    spikes[acts < thresholds]=0
    
    # new stuff 
    if spike_cost>0:
        spike_rep[spikes==1]+=1
    #     spike_rep[spikes==0]-=1
        spike_rep[spikes==0]=0
    #     spike_rep[spike_rep<0]=0
        spikes[spikes==1] -= (1-np.exp(-spike_rep[spikes==1]*spike_cost))
    
    acts[spikes>0]=acts[spikes>0]-thresholds[spikes>0]
    
    if acts_neg == 0:
        acts[acts<0]=0
        
    errors=acts-targets
    
    return acts, spikes, errors, spike_rep

def learning(learn_on,link_mat,prev_spikes, errors,wmat,targets):
    active_neighbors=link_mat.copy()
    active_neighbors[prev_spikes==0,:]=0
    d_wmat = active_neighbors.copy()
    active_neighbors=np.sum(active_neighbors,axis=0)#+np.repeat(1,nnodes)
    
    if learn_on==1:
        if np.sum(active_neighbors) >0:
            d_wmat = errors*d_wmat
            d_wmat=(d_wmat/active_neighbors)
            d_wmat=np.nan_to_num(d_wmat)
            wmat-=d_wmat
            
        targets=targets+(errors*lrate_targ) # could multiply by acts, so that this value naturally can't go below 0? but that will also amplify the change when acts are very high
        targets[targets<targ_min]=targ_min            
        
    return wmat, targets

# %% [markdown]
# # Run the model

# %%
spikes=np.zeros(nnodes)
spike_rep=np.zeros(nnodes)
targets=np.repeat(targ_min,nnodes)
acts=np.zeros(nnodes)
input_acts = np.zeros(2)
output_acts = np.zeros(3)
# output_spikes = np.zeros(2)
# output_targets = np.repeat(targ_min,2)
MeanAbsErs=[]
MeanActs =[]
MeanSpikes=[]

i=1
degree = 0
heading = 180
direction = 1
learn_on=1
position = [0,0]
def drawframe(n):
    global noise_sd,link_decay,spike_rep,circle1, position,direction,degree, heading, acts, input_acts, output_acts, leak, spikes, prev_spikes, wmat, input_wmat, output_wmat, targets, errors,MeanAbsErs,MeanActs,MeanSpikes
    
    if (n %  720 == 0) and (n !=0):
        if direction == 1:
            direction = 2
        else:
            direction = 1
    
    input, dists, angles = get_input_acts(heading, position, degree)
        
    prev_spikes = spikes.copy()
    
    acts, spikes, errors, spike_rep = get_acts(acts,leak,spikes,wmat,input,input_wmat,targets, spike_rep)
    if effector_type == 1:
        output_acts = np.dot(spikes, output_wmat)
    else:
        output_acts = acts[effector_nodes]
        
    wmat, targets = learning(learn_on,link_mat,prev_spikes, errors, wmat,targets)
    
    x, y, sLx, sLy, sRx, sRy = get_plot_vals(degree, heading, position)
    circle1.remove()
    circle1 = plt.Circle((position[0], position[1]), 0.5, color='black', fill = 0)
    
    degree = move_stim(degree, direction)
    heading, position = move_agent(output_acts, heading, position)
    
    ax1.add_patch(circle1)
    
    pt1.set_data(x,y)
    sL.set_data(sLx,sLy)
    sR.set_data(sRx,sRy)

    bar1_plt2.set_height(input[0])
    bar2_plt2.set_height(input[1])
    bar1_plt3.set_height(output_acts[0])
    bar2_plt3.set_height(output_acts[1])
    bar3_plt3.set_height(output_acts[2])
    bar4_plt3.set_height(output_acts[3])
    
#     ax4.clear()
#     netfig=nx.draw_networkx(net,width=.1,with_labels=False, node_size=10, pos = layout, node_color=spikes)
#     #netfig=nx.draw_networkx_nodes(net, node_size=10, pos = layout, node_color=spikes)
#     bar1_plt5.set_height(np.mean(np.abs(acts)))
#     bar2_plt5.set_height(np.mean(np.abs(errors)))
#     bar3_plt5.set_height(np.mean(targets))
#     ax6.clear()
#     ax6.set_ylim((0,150))
#     ax6.set_xlim((-5,5))
#     ax6.hist(x=np.matrix.flatten(wmat[link_mat==1]), bins='auto', alpha=0.7, rwidth=0.85)

    txt_title1.set_text('Frame = {0:4d}'.format(n))
    txt_title2.set_text('M.Err = {0:f}'.format(np.round(np.mean(errors), decimals=2)))
    txt_title3.set_text('M.Act = {0:f}'.format(np.round(np.mean(acts), decimals=2)))
    
    if (n % 100 !=0):
        MeanAbsEr = np.mean(np.abs(errors))
        MeanAbsErs.append(MeanAbsEr)
        MeanAct = np.mean(acts)
        MeanActs.append(MeanAct)
        MeanSpike = np.mean(spikes)
        MeanSpikes.append(MeanSpike)
        #print('iteration: ', n, ' ; MeanAbsEr: ',MeanAbsEr, ' ; MeanAct: ', MeanAct)
        #print('iteration: ', n, ' ; ang_dL: ', angles[0], ' ; ang_dR: ', angles[1], ' ; heading: ', heading, ' ; pos_x: ', position[0], ' ; pos_y: ', position[1])
    else:
        MeanAbsEr = np.mean(np.abs(errors))
        MeanAbsErs.append(MeanAbsEr)
        MeanAct = np.mean(acts)
        MeanActs.append(MeanAct)
        MeanSpike = np.mean(spikes)
        MeanSpikes.append(MeanSpike)
        
        MeanAbsErs_ = np.round(np.mean(MeanAbsErs),decimals=2)
        MeanActs_ = np.round(np.mean(MeanActs),decimals=2)
        MeanSpikes_ = np.round(np.mean(MeanSpikes),decimals=2)
        print('iteration: ', str(n), ' ; MeanAbsErs: ',str(MeanAbsErs_), ' ; MeanAct: ', str(MeanActs_), '; MeanSpikes: ', str(MeanSpikes_))
        MeanAbsErs=[]
        MeanActs=[]
        MeanSpikes=[]
    
    #txt_title2.set_text('MnAbsEr: ' + str(np.mean(np.abs(errors))) + ' ; MnAct: ' + str(np.mean(acts)) + '; MnSpk: ', str(np.mean(spikes)))
    #txt_title2.set_text('MnAbsEr = {0:4d}'.format(np.mean(np.abs(errors))))
    #txt_title2.set_text('iteration: ' + str(n))
    return (pt1,sL,sR)

# create objects that will change in the animation. These are
# initially empty, and will be given new values for each frame
# in the animation.


# create a figure and axes
#fig = plt.figure(figsize=(12,8))
fig = plt.figure(figsize=(10,3))
ax1 = plt.subplot(1,3,1)
ax2 = plt.subplot(1,3,2)
ax3 = plt.subplot(1,3,3)

# ax4 = plt.subplot(2,3,4)
# ax5 = plt.subplot(2,3,5)
# ax6 = plt.subplot(2,3,6)

# set up the subplots as needed
ax1.set_xlim(( -10, 10))            
ax1.set_ylim((-10, 10))
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax2.set_ylim((0, 1))
ax3.set_ylim((0, 10))

# ax5.set_ylim((0,3))
# ax6.set_ylim((0,150))
# ax6.set_xlim((-5,5))

circle1 = plt.Circle((0, 0), 0.5, color='black', fill = 0)
ax1.add_patch(Rectangle((-5, -5), 10, 10,
                       edgecolor = 'black',
                        facecolor = 'blue',
                        fill=False, linestyle = 'dashed',
                        lw=1))
ax1.add_patch(circle1)

# create objects that will change in the animation. These are
# initially empty, and will be given new values for each frame
# in the animation.
txt_title1 = ax1.set_title('')
txt_title2 = ax2.set_title('')
txt_title3 = ax3.set_title('')
#txt_title4 = ax4.set_title('Network Spikes')
#txt_title5 = ax5.set_title('Acts, Errs, Targs')
#txt_title6 = ax6.set_title('Weight Dist.')

pt1, = ax1.plot([], [], 'g.', ms=20)
sL, = ax1.plot([],[], 'r.', ms =3)
sR, = ax1.plot([],[], 'b.', ms =3)
bar1_plt2, bar2_plt2 = ax2.bar(['sensor L', 'sensor R'],[0,0], color = ['r','b'])
bar1_plt3, bar2_plt3, bar3_plt3, bar4_plt3 = ax3.bar(['Left', 'Right', 'Forward', 'Back'],[0,0,0,0], color = ['r','b','black','gray'])
#plt.sca(ax4)
#netfig = nx.draw_networkx(net,width=.1,with_labels=False, node_size=10, pos = layout, node_color=spikes)
# bar1_plt5, bar2_plt5, bar3_plt5 = ax5.bar(['MAct','MErr', 'MTarget'],[0,0,0],color = 'black')
# ax6.hist(x=np.matrix.flatten(wmat[link_mat==1]), bins='auto',alpha=0.7, rwidth=0.85)

spikes=np.zeros(nnodes)
targets=np.repeat(targ_min,nnodes)
acts=np.zeros(nnodes)
input_acts = np.zeros(2)
output_acts = np.zeros(2)
# output_spikes = np.zeros(2)
# output_targets = np.repeat(targ_min,2)
MeanAbsErs=[]
MeanActs =[]
MeanSpikes = []
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
anim = animation.FuncAnimation(fig, drawframe, frames=plotIter, interval=20, blit=True)
#plt.show()
anim.save('MV_BraitenbergReservoir3_X.mp4') #v1
# Out:
# iteration:  0  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  0  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# /Users/jbenfalandays/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:190: RuntimeWarning: invalid value encountered in true_divide
# iteration:  100  ; MeanAbsErs:  1.0  ; MeanAct:  0.01 ; MeanSpikes:  0.0
# iteration:  200  ; MeanAbsErs:  0.78  ; MeanAct:  1.02 ; MeanSpikes:  0.35
# iteration:  300  ; MeanAbsErs:  0.96  ; MeanAct:  0.06 ; MeanSpikes:  0.0
# iteration:  400  ; MeanAbsErs:  0.77  ; MeanAct:  0.59 ; MeanSpikes:  0.18
# iteration:  500  ; MeanAbsErs:  0.68  ; MeanAct:  0.65 ; MeanSpikes:  0.16
# iteration:  600  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  700  ; MeanAbsErs:  0.6  ; MeanAct:  1.0 ; MeanSpikes:  0.28
# iteration:  800  ; MeanAbsErs:  0.52  ; MeanAct:  1.04 ; MeanSpikes:  0.27
# iteration:  900  ; MeanAbsErs:  0.96  ; MeanAct:  0.05 ; MeanSpikes:  0.0
# iteration:  1000  ; MeanAbsErs:  0.73  ; MeanAct:  0.58 ; MeanSpikes:  0.16
# iteration:  1100  ; MeanAbsErs:  0.5  ; MeanAct:  1.04 ; MeanSpikes:  0.27
# iteration:  1200  ; MeanAbsErs:  0.5  ; MeanAct:  1.04 ; MeanSpikes:  0.26
# iteration:  1300  ; MeanAbsErs:  0.47  ; MeanAct:  1.05 ; MeanSpikes:  0.24
# iteration:  1400  ; MeanAbsErs:  0.43  ; MeanAct:  1.05 ; MeanSpikes:  0.21
# iteration:  1500  ; MeanAbsErs:  0.4  ; MeanAct:  1.04 ; MeanSpikes:  0.16
# iteration:  1600  ; MeanAbsErs:  0.72  ; MeanAct:  0.49 ; MeanSpikes:  0.09
# iteration:  1700  ; MeanAbsErs:  0.97  ; MeanAct:  0.08 ; MeanSpikes:  0.02
# iteration:  1800  ; MeanAbsErs:  0.53  ; MeanAct:  1.03 ; MeanSpikes:  0.26
# iteration:  1900  ; MeanAbsErs:  0.75  ; MeanAct:  0.57 ; MeanSpikes:  0.14
# iteration:  2000  ; MeanAbsErs:  0.58  ; MeanAct:  0.86 ; MeanSpikes:  0.23
# iteration:  2100  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  2200  ; MeanAbsErs:  0.68  ; MeanAct:  0.79 ; MeanSpikes:  0.22
# iteration:  2300  ; MeanAbsErs:  0.51  ; MeanAct:  1.03 ; MeanSpikes:  0.28
# iteration:  2400  ; MeanAbsErs:  0.47  ; MeanAct:  1.04 ; MeanSpikes:  0.26
# iteration:  2500  ; MeanAbsErs:  0.41  ; MeanAct:  1.03 ; MeanSpikes:  0.19
# iteration:  2600  ; MeanAbsErs:  0.96  ; MeanAct:  0.05 ; MeanSpikes:  0.0
# iteration:  2700  ; MeanAbsErs:  0.89  ; MeanAct:  0.3 ; MeanSpikes:  0.07
# iteration:  2800  ; MeanAbsErs:  0.75  ; MeanAct:  0.51 ; MeanSpikes:  0.13
# iteration:  2900  ; MeanAbsErs:  0.67  ; MeanAct:  0.77 ; MeanSpikes:  0.23
# iteration:  3000  ; MeanAbsErs:  0.52  ; MeanAct:  1.04 ; MeanSpikes:  0.29
# iteration:  3100  ; MeanAbsErs:  0.51  ; MeanAct:  1.04 ; MeanSpikes:  0.26
# iteration:  3200  ; MeanAbsErs:  0.93  ; MeanAct:  0.12 ; MeanSpikes:  0.02
# iteration:  3300  ; MeanAbsErs:  0.68  ; MeanAct:  0.77 ; MeanSpikes:  0.21
# iteration:  3400  ; MeanAbsErs:  0.77  ; MeanAct:  0.46 ; MeanSpikes:  0.11
# iteration:  3500  ; MeanAbsErs:  0.88  ; MeanAct:  0.3 ; MeanSpikes:  0.07
# iteration:  3600  ; MeanAbsErs:  0.52  ; MeanAct:  1.02 ; MeanSpikes:  0.26
# iteration:  3700  ; MeanAbsErs:  0.75  ; MeanAct:  0.56 ; MeanSpikes:  0.15
# iteration:  3800  ; MeanAbsErs:  0.51  ; MeanAct:  1.03 ; MeanSpikes:  0.27
# iteration:  3900  ; MeanAbsErs:  0.81  ; MeanAct:  0.42 ; MeanSpikes:  0.09
# iteration:  4000  ; MeanAbsErs:  0.55  ; MeanAct:  0.94 ; MeanSpikes:  0.23
# iteration:  4100  ; MeanAbsErs:  0.64  ; MeanAct:  0.76 ; MeanSpikes:  0.19
# iteration:  4200  ; MeanAbsErs:  0.78  ; MeanAct:  0.47 ; MeanSpikes:  0.11
# iteration:  4300  ; MeanAbsErs:  0.54  ; MeanAct:  0.96 ; MeanSpikes:  0.23
# iteration:  4400  ; MeanAbsErs:  0.57  ; MeanAct:  0.82 ; MeanSpikes:  0.2
# iteration:  4500  ; MeanAbsErs:  0.81  ; MeanAct:  0.3 ; MeanSpikes:  0.04
# iteration:  4600  ; MeanAbsErs:  0.8  ; MeanAct:  0.45 ; MeanSpikes:  0.12
# iteration:  4700  ; MeanAbsErs:  0.6  ; MeanAct:  0.84 ; MeanSpikes:  0.23
# iteration:  4800  ; MeanAbsErs:  0.91  ; MeanAct:  0.26 ; MeanSpikes:  0.06
# iteration:  4900  ; MeanAbsErs:  0.54  ; MeanAct:  1.04 ; MeanSpikes:  0.28
# iteration:  5000  ; MeanAbsErs:  0.95  ; MeanAct:  0.08 ; MeanSpikes:  0.0
# iteration:  5100  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  5200  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  5300  ; MeanAbsErs:  0.81  ; MeanAct:  0.46 ; MeanSpikes:  0.12
# iteration:  5400  ; MeanAbsErs:  0.52  ; MeanAct:  1.04 ; MeanSpikes:  0.3
# iteration:  5500  ; MeanAbsErs:  0.48  ; MeanAct:  1.04 ; MeanSpikes:  0.26
# iteration:  5600  ; MeanAbsErs:  0.42  ; MeanAct:  1.03 ; MeanSpikes:  0.21
# iteration:  5700  ; MeanAbsErs:  0.39  ; MeanAct:  1.05 ; MeanSpikes:  0.18
# iteration:  5800  ; MeanAbsErs:  0.6  ; MeanAct:  0.85 ; MeanSpikes:  0.17
# iteration:  5900  ; MeanAbsErs:  0.55  ; MeanAct:  1.02 ; MeanSpikes:  0.26
# iteration:  6000  ; MeanAbsErs:  0.97  ; MeanAct:  0.04 ; MeanSpikes:  0.0
# iteration:  6100  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  6200  ; MeanAbsErs:  0.62  ; MeanAct:  0.89 ; MeanSpikes:  0.24
# iteration:  6300  ; MeanAbsErs:  0.93  ; MeanAct:  0.1 ; MeanSpikes:  0.01
# iteration:  6400  ; MeanAbsErs:  0.81  ; MeanAct:  0.46 ; MeanSpikes:  0.13
# iteration:  6500  ; MeanAbsErs:  0.71  ; MeanAct:  0.59 ; MeanSpikes:  0.15
# iteration:  6600  ; MeanAbsErs:  0.87  ; MeanAct:  0.28 ; MeanSpikes:  0.05
# iteration:  6700  ; MeanAbsErs:  0.76  ; MeanAct:  0.49 ; MeanSpikes:  0.13
# iteration:  6800  ; MeanAbsErs:  0.58  ; MeanAct:  0.92 ; MeanSpikes:  0.25
# iteration:  6900  ; MeanAbsErs:  0.5  ; MeanAct:  1.04 ; MeanSpikes:  0.27
# iteration:  7000  ; MeanAbsErs:  0.48  ; MeanAct:  1.05 ; MeanSpikes:  0.25
# iteration:  7100  ; MeanAbsErs:  0.45  ; MeanAct:  0.98 ; MeanSpikes:  0.18
# iteration:  7200  ; MeanAbsErs:  0.66  ; MeanAct:  0.76 ; MeanSpikes:  0.2
# iteration:  7300  ; MeanAbsErs:  0.51  ; MeanAct:  1.03 ; MeanSpikes:  0.26
# iteration:  7400  ; MeanAbsErs:  0.69  ; MeanAct:  0.6 ; MeanSpikes:  0.12
# iteration:  7500  ; MeanAbsErs:  0.97  ; MeanAct:  0.05 ; MeanSpikes:  0.01
# iteration:  7600  ; MeanAbsErs:  0.55  ; MeanAct:  1.04 ; MeanSpikes:  0.29
# iteration:  7700  ; MeanAbsErs:  0.48  ; MeanAct:  1.04 ; MeanSpikes:  0.24
# iteration:  7800  ; MeanAbsErs:  0.82  ; MeanAct:  0.34 ; MeanSpikes:  0.07
# iteration:  7900  ; MeanAbsErs:  0.92  ; MeanAct:  0.2 ; MeanSpikes:  0.05
# iteration:  8000  ; MeanAbsErs:  0.51  ; MeanAct:  1.04 ; MeanSpikes:  0.28
# iteration:  8100  ; MeanAbsErs:  0.45  ; MeanAct:  1.04 ; MeanSpikes:  0.22
# iteration:  8200  ; MeanAbsErs:  0.53  ; MeanAct:  0.79 ; MeanSpikes:  0.12
# iteration:  8300  ; MeanAbsErs:  0.58  ; MeanAct:  0.98 ; MeanSpikes:  0.26
# iteration:  8400  ; MeanAbsErs:  0.51  ; MeanAct:  1.04 ; MeanSpikes:  0.29
# iteration:  8500  ; MeanAbsErs:  0.46  ; MeanAct:  1.04 ; MeanSpikes:  0.24
# iteration:  8600  ; MeanAbsErs:  0.43  ; MeanAct:  1.01 ; MeanSpikes:  0.17
# iteration:  8700  ; MeanAbsErs:  0.7  ; MeanAct:  0.63 ; MeanSpikes:  0.15
# iteration:  8800  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  8900  ; MeanAbsErs:  0.66  ; MeanAct:  0.8 ; MeanSpikes:  0.22
# iteration:  9000  ; MeanAbsErs:  0.54  ; MeanAct:  0.94 ; MeanSpikes:  0.24
# iteration:  9100  ; MeanAbsErs:  0.57  ; MeanAct:  1.02 ; MeanSpikes:  0.3
# iteration:  9200  ; MeanAbsErs:  0.81  ; MeanAct:  0.4 ; MeanSpikes:  0.09
# iteration:  9300  ; MeanAbsErs:  0.81  ; MeanAct:  0.45 ; MeanSpikes:  0.13
# iteration:  9400  ; MeanAbsErs:  0.56  ; MeanAct:  0.92 ; MeanSpikes:  0.23
# iteration:  9500  ; MeanAbsErs:  0.66  ; MeanAct:  0.74 ; MeanSpikes:  0.18
# iteration:  9600  ; MeanAbsErs:  0.83  ; MeanAct:  0.33 ; MeanSpikes:  0.06
# iteration:  9700  ; MeanAbsErs:  0.66  ; MeanAct:  0.73 ; MeanSpikes:  0.17
# iteration:  9800  ; MeanAbsErs:  0.53  ; MeanAct:  1.04 ; MeanSpikes:  0.31
# iteration:  9900  ; MeanAbsErs:  0.48  ; MeanAct:  1.05 ; MeanSpikes:  0.26
# iteration:  10000  ; MeanAbsErs:  0.42  ; MeanAct:  1.02 ; MeanSpikes:  0.18
# iteration:  10100  ; MeanAbsErs:  0.44  ; MeanAct:  1.04 ; MeanSpikes:  0.22
# iteration:  10200  ; MeanAbsErs:  0.87  ; MeanAct:  0.21 ; MeanSpikes:  0.03
# iteration:  10300  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  10400  ; MeanAbsErs:  0.78  ; MeanAct:  0.53 ; MeanSpikes:  0.13
# iteration:  10500  ; MeanAbsErs:  0.68  ; MeanAct:  0.68 ; MeanSpikes:  0.17
# iteration:  10600  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  10700  ; MeanAbsErs:  0.77  ; MeanAct:  0.53 ; MeanSpikes:  0.13
# iteration:  10800  ; MeanAbsErs:  0.53  ; MeanAct:  1.03 ; MeanSpikes:  0.29
# iteration:  10900  ; MeanAbsErs:  0.64  ; MeanAct:  0.73 ; MeanSpikes:  0.16
# iteration:  11000  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  11100  ; MeanAbsErs:  0.95  ; MeanAct:  0.08 ; MeanSpikes:  0.01
# iteration:  11200  ; MeanAbsErs:  0.65  ; MeanAct:  0.78 ; MeanSpikes:  0.21
# iteration:  11300  ; MeanAbsErs:  0.57  ; MeanAct:  0.89 ; MeanSpikes:  0.24
# iteration:  11400  ; MeanAbsErs:  0.82  ; MeanAct:  0.38 ; MeanSpikes:  0.07
# iteration:  11500  ; MeanAbsErs:  0.67  ; MeanAct:  0.61 ; MeanSpikes:  0.12
# iteration:  11600  ; MeanAbsErs:  0.69  ; MeanAct:  0.63 ; MeanSpikes:  0.16
# iteration:  11700  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  11800  ; MeanAbsErs:  0.8  ; MeanAct:  0.48 ; MeanSpikes:  0.11
# iteration:  11900  ; MeanAbsErs:  0.61  ; MeanAct:  0.88 ; MeanSpikes:  0.2
# iteration:  12000  ; MeanAbsErs:  0.66  ; MeanAct:  0.83 ; MeanSpikes:  0.24
# iteration:  12100  ; MeanAbsErs:  0.51  ; MeanAct:  1.01 ; MeanSpikes:  0.26
# iteration:  12200  ; MeanAbsErs:  0.89  ; MeanAct:  0.28 ; MeanSpikes:  0.06
# iteration:  12300  ; MeanAbsErs:  0.55  ; MeanAct:  1.04 ; MeanSpikes:  0.29
# iteration:  12400  ; MeanAbsErs:  0.71  ; MeanAct:  0.58 ; MeanSpikes:  0.13
# iteration:  12500  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  12600  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  12700  ; MeanAbsErs:  0.61  ; MeanAct:  0.92 ; MeanSpikes:  0.25
# iteration:  12800  ; MeanAbsErs:  0.47  ; MeanAct:  1.04 ; MeanSpikes:  0.25
# iteration:  12900  ; MeanAbsErs:  0.46  ; MeanAct:  0.97 ; MeanSpikes:  0.2
# iteration:  13000  ; MeanAbsErs:  0.99  ; MeanAct:  0.01 ; MeanSpikes:  0.0
# iteration:  13100  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  13200  ; MeanAbsErs:  0.67  ; MeanAct:  0.78 ; MeanSpikes:  0.2
# iteration:  13300  ; MeanAbsErs:  0.49  ; MeanAct:  1.04 ; MeanSpikes:  0.23
# iteration:  13400  ; MeanAbsErs:  0.52  ; MeanAct:  1.04 ; MeanSpikes:  0.26
# iteration:  13500  ; MeanAbsErs:  0.96  ; MeanAct:  0.05 ; MeanSpikes:  0.0
# iteration:  13600  ; MeanAbsErs:  0.83  ; MeanAct:  0.42 ; MeanSpikes:  0.11
# iteration:  13700  ; MeanAbsErs:  0.57  ; MeanAct:  0.92 ; MeanSpikes:  0.23
# iteration:  13800  ; MeanAbsErs:  1.0  ; MeanAct:  0.0 ; MeanSpikes:  0.0
# iteration:  13900  ; MeanAbsErs:  0.63  ; MeanAct:  0.85 ; MeanSpikes:  0.22
# iteration:  14000  ; MeanAbsErs:  0.6  ; MeanAct:  0.9 ; MeanSpikes:  0.25
# iteration:  14100  ; MeanAbsErs:  0.58  ; MeanAct:  0.94 ; MeanSpikes:  0.23
# iteration:  14200  ; MeanAbsErs:  0.52  ; MeanAct:  1.04 ; MeanSpikes:  0.29
# iteration:  14300  ; MeanAbsErs:  0.61  ; MeanAct:  0.73 ; MeanSpikes:  0.16

# %%
### alternate way to plot
#HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-125-f885f4acf935> in <module>()
# ----> 1 HTML(anim.to_html5_video())
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1334                                 bitrate=mpl.rcParams['animation.bitrate'],
#    1335                                 fps=1000. / self._interval)
# -> 1336                 self.save(str(path), writer=writer)
#    1337                 # Now open and base64 encode.
#    1338                 vid64 = base64.encodebytes(path.read_bytes())
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1142                                _is_saving=True, manager=None):
#    1143             for anim in all_anim:
# -> 1144                 anim._init_draw()  # Clear the initial frame
#    1145             frame_number = 0
#    1146             # TODO: Currently only FuncAnimation has a save_count
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in _init_draw(self)
#    1717         # artists.
#    1718         if self._init_func is None:
# -> 1719             self._draw_frame(next(self.new_frame_seq()))
#    1720
#    1721         else:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1740         # Call the func with framedata and args. If blitting is desired,
#    1741         # func needs to return a sequence of any artists that were modified.
# -> 1742         self._drawn_artists = self._func(framedata, *self._args)
#    1743         if self._blit:
#    1744             if self._drawn_artists is None:
#
# <ipython-input-123-fe8b0f146f79> in drawframe(n)
#      33     output_acts = np.dot(spikes, output_wmat)
#      34
# ---> 35     wmat, targets = learning(learn_on,link_mat,prev_spikes, errors, wmat,targets)
#      36
#      37     x, y, sLx, sLy, sRx, sRy = get_plot_vals(degree, heading, position)
#
# <ipython-input-122-dbd4a23592b6> in learning(learn_on, link_mat, prev_spikes, errors, wmat, targets)
#     193     active_neighbors[prev_inactive,:]=0
#     194     active_neighbors=np.sum(active_neighbors,axis=0)#+np.repeat(1,nnodes)
# --> 195     w_mat = w_mat*(1-link_decay)
#     196
#     197     if learn_on==1:
#
# UnboundLocalError: local variable 'w_mat' referenced before assignment
